# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("retail_sales_clean.csv")
df.head()
# Out:
#    Order ID  Order Date Region    Category Sub-Category Customer Name  \
# 0  ORD-1000  2024-10-16   East   Furniture    Bookcases   Customer_63
# 1  ORD-1001  2023-04-15   East  Technology      Copiers    Customer_9
# 2  ORD-1002  2023-08-12   West  Technology       Phones  Customer_144
# 3  ORD-1003  2023-08-14  South  Technology  Accessories    Customer_2
# 4  ORD-1004  2023-12-15  North   Furniture       Tables   Customer_87
#
#    Quantity  Discount   Sales  Profit
# 0         4       0.0  774.08  259.48
# 1         1       0.0  368.68   84.65
# 2         4       0.3  242.06  -34.66
# 3         3       0.3   80.77    5.64
# 4         2       0.0  609.10  137.75

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       2000 non-null   object
#  1   Order Date     2000 non-null   object
#  2   Region         2000 non-null   object
#  3   Category       2000 non-null   object
#  4   Sub-Category   2000 non-null   object
#  5   Customer Name  2000 non-null   object
#  6   Quantity       2000 non-null   int64
#  7   Discount       2000 non-null   float64
#  8   Sales          2000 non-null   float64
#  9   Profit         2000 non-null   float64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 156.4+ KB

# %%
df.describe()
# Out:
#           Quantity     Discount        Sales       Profit
# count  2000.000000  2000.000000  2000.000000  2000.000000
# mean      6.540500     0.145950  1424.861445   148.795555
# std       3.410451     0.140956  1243.421452   292.314794
# min       1.000000     0.000000    10.710000  -758.270000
# 25%       4.000000     0.000000   425.510000    -6.095000
# 50%       7.000000     0.150000  1046.560000    61.040000
# 75%      10.000000     0.300000  2131.182500   225.582500
# max      12.000000     0.400000  5889.360000  1811.700000

# %%
df.isnull().sum()
# Out:
# Order ID         0
# Order Date       0
# Region           0
# Category         0
# Sub-Category     0
# Customer Name    0
# Quantity         0
# Discount         0
# Sales            0
# Profit           0
# dtype: int64

# %%
df['Region'] = df['Region'].fillna('Unknown')
df['Profit'] = df.groupby('Category')['Profit'].transform(lambda x: x.fillna(x.mean()))
df.isnull().sum()
# Out:
# Order ID         0
# Order Date       0
# Region           0
# Category         0
# Sub-Category     0
# Customer Name    0
# Quantity         0
# Discount         0
# Sales            0
# Profit           0
# dtype: int64

# %%
category_sales = df.groupby('Category')['Sales'].sum()
category_sales.plot(kind='bar', color='teal')
plt.title('Total Sales by Category')
plt.ylabel('Sales')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=df, x='Discount', y='Profit', hue='Category')
plt.title('Discount vs Profit')
plt.show()

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], errors='coerce')
monthly_sales = df.groupby(df['Order Date'].dt.to_period('M'))['Sales'].sum()

plt.figure(figsize=(10,5))
monthly_sales.plot(kind='line', marker='o', color='darkorange')
plt.title('Monthly Sales Trend')
plt.ylabel('Sales')
plt.xlabel('Month')
plt.xticks(rotation=45)
plt.show()
